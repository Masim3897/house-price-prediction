# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
from pandas.api.types import CategoricalDtype

# %%
import seaborn as sns

# %% [markdown]
# ## load dataset

# %%
train_data_path = r"C:\Users\Dell\projects\house_price_prediction\data\train.csv"
test_data_path = r"C:\Users\Dell\projects\house_price_prediction\data\test.csv"


df_train = pd.read_csv(train_data_path)
df_test = pd.read_csv(test_data_path)

print("shape of df_train: ",df_train.shape)
print("shape of df_test: ",df_test.shape)
# Out:
# shape of df_train:  (1460, 81)
# shape of df_test:  (1459, 80)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_columns", None)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Data Integration

# %%
df = pd.concat([df_train, df_test])
print("shape of integrated data: ",df.shape)
# Out:
# shape of integrated data:  (2919, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## get the brief information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %%
int_features = df.select_dtypes(include = ["int64"]).columns
print("total number of int features: ",int_features.shape[0])
print("int feature name: ",int_features.tolist())
# Out:
# total number of int features:  26
# int feature name:  ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
float_features = df.select_dtypes(include = ["float64"]).columns
print("total number of float features: ",float_features.shape[0])
print("float feature name: ",float_features.tolist())
# Out:
# total number of float features:  12
# float feature name:  ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'SalePrice']

# %%
object_features = df.select_dtypes(include = ["object"]).columns
print("total number of object features: ",object_features.shape[0])
print("object feature name: ",object_features.tolist())
# Out:
# total number of object features:  43
# object feature name:  ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ## get the statistical information of numarical features

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
df.describe().shape
# Out:
# (8, 38)

# %% [markdown]
# ## visualize the missing value

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.isnull())
plt.savefig("EDA_img\heatmap_null_value.png")

# %% [markdown]
# ## get the null value percentage for every feature

# %%
df = df.set_index("Id")

# %%
null_count = df.isnull().sum()
null_count
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# Length: 80, dtype: int64

# %%
null_percentage = df.isnull().sum()/df.shape[0]*100
null_percentage
# Out:
# MSSubClass        0.000000
# MSZoning          0.137033
# LotFrontage      16.649538
# LotArea           0.000000
# Street            0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.034258
# SaleCondition     0.000000
# SalePrice        49.982871
# Length: 80, dtype: float64

# %% [markdown]
# ## missing value columns

# %%
missing_value_50_perc = null_percentage[null_percentage > 50]
missing_value_50_perc
# Out:
# Alley          93.216855
# MasVnrType     60.500171
# PoolQC         99.657417
# Fence          80.438506
# MiscFeature    96.402878
# dtype: float64

# %%
missing_value_20_50_perc = null_percentage[(null_percentage > 20) & (null_percentage < 51)]
missing_value_20_50_perc
# Out:
# FireplaceQu    48.646797
# SalePrice      49.982871
# dtype: float64

# %%
missing_value_5_20_perc = null_percentage[(null_percentage > 5) & (null_percentage < 21)]
missing_value_5_20_perc
# Out:
# LotFrontage     16.649538
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# dtype: float64

# %% [markdown]
# ## missing value imputation

# %%
missing_value_feature = null_percentage[null_percentage > 0]
print("total missing value= ", len(missing_value_feature))
missing_value_feature
# Out:
# total missing value=  35
# MSZoning         0.137033
# LotFrontage     16.649538
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# ...

# %%
object_na_feature=missing_value_feature[missing_value_feature.keys().isin(object_features)]
print("total missing object feature = ", len(object_na_feature))
object_na_feature
# Out:
# total missing object feature =  23
# MSZoning         0.137033
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
# Electrical       0.034258
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# dtype: float64

# %%
int_na_feature=missing_value_feature[missing_value_feature.keys().isin(int_features)]
print("total missing object feature = ", len(int_na_feature))
int_na_feature
# Out:
# total missing object feature =  0
# Series([], dtype: float64)

# %%
float_na_feature=missing_value_feature[missing_value_feature.keys().isin(float_features)]
print("total missing object feature = ", len(float_na_feature))
float_na_feature
# Out:
# total missing object feature =  12
# LotFrontage     16.649538
# MasVnrArea       0.787941
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# GarageYrBlt      5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# SalePrice       49.982871
# dtype: float64

# %% [markdown]
# ## handling MSZoning missing value = 0.137033

# %%
df["MSZoning"].value_counts()
# Out:
# MSZoning
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: count, dtype: int64

# %%
## copy the original data 
df_copy = df.copy()
df_copy.shape
# Out:
# (2919, 80)

# %%
mszoning_mode= df["MSZoning"].mode()[0]
df_copy["MSZoning"].replace(np.nan, mszoning_mode, inplace=True)
df_copy["MSZoning"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling Alley missing value = 93.216855

# %%
df_copy["Alley"].value_counts()
# Out:
# Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64

# %%
alley_cont= "NA" 
df_copy["Alley"].replace(np.nan, alley_cont, inplace=True)
df_copy["Alley"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling LotFrontage missing value =16.649538

# %%
df_copy["LotFrontage"].value_counts()
# Out:
# LotFrontage
# 60.0     276
# 80.0     137
# 70.0     133
# 50.0     117
# 75.0     105
#         ...
# 152.0      1
# 138.0      1
# 182.0      1
# 168.0      1
# 133.0      1
# Name: count, Length: 128, dtype: int64

# %%
lotfrontage_mean= df["LotFrontage"].mean()
df_copy["LotFrontage"].replace(np.nan, lotfrontage_mean, inplace=True)
df_copy["LotFrontage"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling Utilities missing value=0.068517

# %%
df_copy["Utilities"].value_counts()
# Out:
# Utilities
# AllPub    2916
# NoSeWa       1
# Name: count, dtype: int64

# %%
utility_mode= df["LotFrontage"].mode()[0]
df_copy["Utilities"].replace(np.nan, utility_mode, inplace=True)
df_copy["Utilities"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling Exterior1st= 0.034258 && Exterior2nd= 0.034258

# %%
df_copy["Exterior1st"].value_counts()
# Out:
# Exterior1st
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# Stone         2
# CBlock        2
# ImStucc       1
# Name: count, dtype: int64

# %%
df_copy["Exterior2nd"].value_counts()
# Out:
# Exterior2nd
# VinylSd    1014
# MetalSd     447
# HdBoard     406
# Wd Sdng     391
# Plywood     270
# CmentBd     126
# Wd Shng      81
# BrkFace      47
# Stucco       47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# Name: count, dtype: int64

# %%
exterior1st_mode= df["Exterior1st"].mode()[0]
df_copy["Exterior1st"].replace(np.nan, exterior1st_mode, inplace=True)
exterior2nd_mode= df["Exterior2nd"].mode()[0]
df_copy["Exterior2nd"].replace(np.nan, exterior2nd_mode, inplace=True)
print("E1st is null: ",df_copy["Exterior1st"].isnull().sum())
print("E2nd is null: ",df_copy["Exterior2nd"].isnull().sum())
# Out:
# E1st is null:  0
# E2nd is null:  0

# %% [markdown]
# ## handling MasVnrType= 60.500171 && MasVnrArea = 0.787941

# %%
sns.heatmap(df[["MasVnrType", "MasVnrArea"]].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
df_copy["MasVnrType"].value_counts()
# Out:
# MasVnrType
# BrkFace    879
# Stone      249
# BrkCmn      25
# Name: count, dtype: int64

# %%
masvnrtype_mode= df["MasVnrType"].mode()[0]
df_copy["MasVnrType"].replace(np.nan, masvnrtype_mode, inplace=True)
df_copy["MasVnrType"].isnull().sum()
# Out:
# 0

# %%
df_copy["MasVnrArea"].value_counts()
# Out:
# MasVnrArea
# 0.0      1738
# 120.0      15
# 176.0      13
# 200.0      13
# 216.0      12
#          ...
# 137.0       1
# 274.0       1
# 415.0       1
# 760.0       1
# 382.0       1
# Name: count, Length: 444, dtype: int64

# %%
masvnrarea_cont= 0
df_copy["MasVnrArea"].replace(np.nan, masvnrarea_cont, inplace=True)
df_copy["MasVnrArea"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling bsmt features

# %% [raw]
# ##cat_bsmt_feature
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
#
# ##num_bsmt_feature
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517

# %%
cat_bsmt_feat=["BsmtQual",        
"BsmtCond",     
"BsmtExposure",    
"BsmtFinType1",     
"BsmtFinType2"]    

num_bsmt_feat=["BsmtFinSF1",      
"BsmtFinSF2",      
"BsmtUnfSF"  ,      
"TotalBsmtSF",      
"BsmtFullBath",    
"BsmtHalfBath"]

# %%
for feat in cat_bsmt_feat:
    print(f"value count of {feat}: {df[feat].value_counts()}")
# Out:
# value count of BsmtQual: BsmtQual
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: count, dtype: int64
# value count of BsmtCond: BsmtCond
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: count, dtype: int64
# value count of BsmtExposure: BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: count, dtype: int64
# value count of BsmtFinType1: BsmtFinType1
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: count, dtype: int64
# value count of BsmtFinType2: BsmtFinType2
# Unf    2493
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: count, dtype: int64

# %%
bsmt_count = "NA"
for feat in cat_bsmt_feat:
    df_copy[feat].replace(np.nan,bsmt_count, inplace=True)

# %%
df_copy[cat_bsmt_feat].isnull().sum()
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# dtype: int64

# %%
bsmt_num = 0
for feat in num_bsmt_feat:
    df_copy[feat].replace(np.nan,bsmt_num, inplace=True)

# %%
df_copy[num_bsmt_feat].isnull().sum()
# Out:
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# dtype: int64

# %% [markdown]
# ## handling Electrical=0.034258 && KitchenQual=0.034258

# %%
electrical_mode= df["Electrical"].mode()[0]
df_copy["Electrical"].replace(np.nan, electrical_mode, inplace=True)
df_copy["Electrical"].isnull().sum()
# Out:
# 0

# %%
KitchenQual_mode= df["KitchenQual"].mode()[0]
df_copy["KitchenQual"].replace(np.nan, KitchenQual_mode, inplace=True)
df_copy["KitchenQual"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling Functional=0.068517

# %%
df["Functional"].value_counts()
# Out:
# Functional
# Typ     2717
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: count, dtype: int64

# %%
functional_mode= df["Functional"].mode()[0]
df_copy["Functional"].replace(np.nan, functional_mode, inplace=True)
df_copy["Functional"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling SaleType=0.034258

# %%
df["SaleType"].value_counts()
# Out:
# SaleType
# WD       2525
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# Name: count, dtype: int64

# %%
saletype_mode= df["SaleType"].mode()[0]
df_copy["SaleType"].replace(np.nan, saletype_mode, inplace=True)
df_copy["SaleType"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling FireplaceQu=48.646797,PoolQC=99.657417,Fence=80.438506,MiscFeature=96.402878

# %%
cat_feat = ["FireplaceQu","PoolQC","Fence","MiscFeature"]
for feat in cat_feat:
    print(f"value count of {feat}: {df[feat].value_counts()}")
# Out:
# value count of FireplaceQu: FireplaceQu
# Gd    744
# TA    592
# Fa     74
# Po     46
# Ex     43
# Name: count, dtype: int64
# value count of PoolQC: PoolQC
# Ex    4
# Gd    4
# Fa    2
# Name: count, dtype: int64
# value count of Fence: Fence
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: count, dtype: int64
# value count of MiscFeature: MiscFeature
# Shed    95
# Gar2     5
# Othr     4
# TenC     1
# Name: count, dtype: int64

# %%
fireplaceQu= "NA"
df_copy["FireplaceQu"].replace(np.nan, fireplaceQu, inplace=True)
df_copy["FireplaceQu"].isnull().sum()
# Out:
# 0

# %%
poolQC= "NA"
df_copy["PoolQC"].replace(np.nan, poolQC, inplace=True)
df_copy["PoolQC"].isnull().sum()
# Out:
# 0

# %%
fence= "NA"
df_copy["Fence"].replace(np.nan, fence, inplace=True)
df_copy["Fence"].isnull().sum()
# Out:
# 0

# %%
miscfeature= "NA"
df_copy["MiscFeature"].replace(np.nan, miscfeature, inplace=True)
df_copy["MiscFeature"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handling garage value

# %%
cat_garage_feat = ["GarageType","GarageFinish","GarageQual","GarageCond"]
num_garage_feat = ["GarageYrBlt","GarageCars","GarageArea"]

df_garafe = df[cat_garage_feat + num_garage_feat]
df_garafe[df_garafe.isnull().any(axis=1)]
# Out:
#      GarageType GarageFinish GarageQual GarageCond  GarageYrBlt  GarageCars  \
# Id
# 40          NaN          NaN        NaN        NaN          NaN         0.0
# 49          NaN          NaN        NaN        NaN          NaN         0.0
# 79          NaN          NaN        NaN        NaN          NaN         0.0
# 89          NaN          NaN        NaN        NaN          NaN         0.0
# 90          NaN          NaN        NaN        NaN          NaN         0.0
# ...         ...          ...        ...        ...          ...         ...
# 2894        NaN          NaN        NaN        NaN          NaN         0.0
# 2910        NaN          NaN        NaN        NaN          NaN         0.0
# 2914        NaN          NaN        NaN        NaN          NaN         0.0
# 2915        NaN          NaN        NaN        NaN          NaN         0.0
# 2918        NaN          NaN        NaN        NaN          NaN         0.0
#
#       GarageArea
# Id
# 40           0.0
# ...

# %%
garage_cont = "NA"
for feat in cat_garage_feat:
    df_copy[feat].replace(np.nan,garage_cont, inplace=True)
    
df_copy[cat_garage_feat].isnull().sum()
# Out:
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
garage_num = "NA"
for feat in num_garage_feat:
    df_copy[feat].replace(np.nan,garage_num, inplace=True)
    
df_copy[num_garage_feat].isnull().sum()
# Out:
# GarageYrBlt    0
# GarageCars     0
# GarageArea     0
# dtype: int64

# %% [markdown]
# ## feature transformation
# ## convert numerical into categogorical feature

# %%
for_num_conv = ["MSSubClass","YearBuilt","YearRemodAdd","GarageYrBlt","MoSold","YrSold"]
for feat in for_num_conv:
  print(f"{feat} data type = {df_copy[feat].dtype}")
# Out:
# MSSubClass data type = int64
# YearBuilt data type = int64
# YearRemodAdd data type = int64
# GarageYrBlt data type = object
# MoSold data type = int64
# YrSold data type = int64

# %%
df_copy[for_num_conv].head()
# Out:
#     MSSubClass  YearBuilt  YearRemodAdd GarageYrBlt  MoSold  YrSold
# Id
# 1           60       2003          2003      2003.0       2    2008
# 2           20       1976          1976      1976.0       5    2007
# 3           60       2001          2002      2001.0       9    2008
# 4           70       1915          1970      1998.0       2    2006
# 5           60       2000          2000      2000.0      12    2008

# %%
df_copy["MoSold"].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %%
calendar.month_abbr[12]
# Out:
# 'Dec'

# %%
# df_copy["MoSold"] = df_copy["MoSold"].apply(lambda x : calendar.month_abbr[x]) accurs error in this line
for feat in for_num_conv:
    df_copy[feat] = df_copy[feat].astype(str)

# %%
for_num_conv = ["MSSubClass","YearBuilt","YearRemodAdd","GarageYrBlt","MoSold","YrSold"]
for feat in for_num_conv:
  print(f"{feat} data type = {df_copy[feat].dtype}")
# Out:
# MSSubClass data type = object
# YearBuilt data type = object
# YearRemodAdd data type = object
# GarageYrBlt data type = object
# MoSold data type = object
# YrSold data type = object

# %% [markdown]
# ## convert categogorical into numerical  feature

# %%
ordinal_end_var = [
    "ExterQual","ExterCond","BsmtQual","BsmtCond","BsmtExposure",
    "BsmtFinType1","BsmtFinSF1","BsmtFinType2",
    "HeatingQC","KitchenQual","FireplaceQu","GarageQual",
    "GarageCond","PoolQC","Functional","GarageFinish","PavedDrive","Utilities"]
print("total number of featues:",len(ordinal_end_var))
# Out:
# total number of featues: 18

# %%
df_copy["ExterQual"].value_counts()
# Out:
# ExterQual
# TA    1798
# Gd     979
# Ex     107
# Fa      35
# Name: count, dtype: int64

# %%
df_copy["ExterQual"] = df_copy["ExterQual"].astype(CategoricalDtype(categories=["Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes

# %%
df_copy["ExterQual"].value_counts()
# Out:
# ExterQual
# 2    1798
# 3     979
# 4     107
# 1      35
# Name: count, dtype: int64

# %%
df_copy["BsmtExposure"].value_counts()
# Out:
# BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# NA      82
# Name: count, dtype: int64

# %%
df_copy["BsmtExposure"] = df_copy["BsmtExposure"].astype(CategoricalDtype(categories=["NA ","No","Mn","Av","Gd"], ordered = True)).cat.codes

# %%
df_copy["BsmtExposure"].value_counts()
# Out:
# BsmtExposure
#  1    1904
#  3     418
#  4     276
#  2     239
# -1      82
# Name: count, dtype: int64

# %%
df_copy["ExterCond"] = df_copy["ExterCond"].astype(CategoricalDtype(categories=["Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["BsmtQual"] = df_copy["BsmtQual"].astype(CategoricalDtype(categories=["NA","Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["BsmtCond"] = df_copy["BsmtCond"].astype(CategoricalDtype(categories=["NA","Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["BsmtFinType1"] = df_copy["BsmtFinType1"].astype(CategoricalDtype(categories=["NA","Unf","LwQ","Rec","BLQ","ALQ","GLQ"], ordered = True)).cat.codes
df_copy["BsmtFinType2"] = df_copy["BsmtFinType2"].astype(CategoricalDtype(categories=["NA","Unf","LwQ","Rec","BLQ","ALQ","GLQ"], ordered = True)).cat.codes
df_copy["HeatingQC"] = df_copy["HeatingQC"].astype(CategoricalDtype(categories=["Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["KitchenQual"] = df_copy["KitchenQual"].astype(CategoricalDtype(categories=["Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["FireplaceQu"] = df_copy["FireplaceQu"].astype(CategoricalDtype(categories=["NA","Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["GarageQual"] = df_copy["GarageQual"].astype(CategoricalDtype(categories=["NA","Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["GarageCond"] = df_copy["GarageCond"].astype(CategoricalDtype(categories=["NA","Po","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["PoolQC"] = df_copy["PoolQC"].astype(CategoricalDtype(categories=["NA","Fa","TA","Gd","Ex"], ordered = True)).cat.codes
df_copy["Functional"] = df_copy["Functional"].astype(CategoricalDtype(categories=["Sal","Sev","Maj2","Maj1","Mod","Min2","Min1"], ordered = True)).cat.codes
df_copy["GarageFinish"] = df_copy["GarageFinish"].astype(CategoricalDtype(categories=["NA","Unf","RFn","Fin"], ordered = True)).cat.codes
df_copy["PavedDrive"] = df_copy["PavedDrive"].astype(CategoricalDtype(categories=["N","P","Y"], ordered = True)).cat.codes
df_copy["Utilities"] = df_copy["Utilities"].astype(CategoricalDtype(categories=["ELO","NoSeWa","NoSewr","AllPub"], ordered = True)).cat.codes
